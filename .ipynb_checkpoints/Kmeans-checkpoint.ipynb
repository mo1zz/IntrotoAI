# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.cluster import MiniBatchKMeans
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Load Data

# %%
# Load the data
df = pd.read_csv(r'C:\Users\44757\Documents\GitHub\IntrotoAI\cleaned_data.csv')

# %% [markdown]
# K-Means

# %%
# Define features
numeric_features = ['BMI', 'PhysicalHealthDays', 'MentalHealthDays', 'SleepHours', 'WeightInKilograms', 'HeightInMeters']
categorical_features = ['State', 'Sex', 'GeneralHealth', 'LastCheckupTime', 'PhysicalActivities',
                        'RemovedTeeth', 'HadAngina', 'HadStroke', 'HadAsthma', 'HadSkinCancer', 
                        'HadCOPD', 'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis', 
                        'HadDiabetes', 'DeafOrHardOfHearing', 'BlindOrVisionDifficulty', 
                        'DifficultyConcentrating', 'DifficultyWalking', 'DifficultyDressingBathing', 
                        'DifficultyErrands', 'SmokerStatus', 'ECigaretteUsage', 'ChestScan', 
                        'RaceEthnicityCategory', 'AgeCategory', 'AlcoholDrinkers', 'HIVTesting', 
                        'FluVaxLast12', 'PneumoVaxEver', 'TetanusLast10Tdap', 'HighRiskLastYear', 'CovidPos']

# Encoding
le = LabelEncoder()
df['HadHeartAttack'] = le.fit_transform(df['HadHeartAttack'])

# Create preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'), categorical_features)
    ])

# Fit preprocessing and PCA, then perform clustering
X_preprocessed = preprocessor.fit_transform(df[numeric_features + categorical_features])

# Check dimensions
print(f"Dimensions after preprocessing: {X_preprocessed.shape}")

# Apply PCA
pca = PCA(n_components=5)  # Reduce n_components to manageable size
X_transformed = pca.fit_transform(X_preprocessed)

# Check dimensions
print(f"Dimensions after PCA: {X_transformed.shape}")

# Perform clustering
kmeans = MiniBatchKMeans(n_clusters=2, random_state=42)
kmeans.fit(X_transformed)

# Get cluster labels
cluster_labels = kmeans.predict(X_transformed)

# Add cluster labels to the dataframe
df['Cluster'] = cluster_labels

# Visualize results
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df['BMI'], df['PhysicalHealthDays'], c=df['Cluster'], cmap='viridis')
plt.colorbar(scatter)
plt.title('K-means Clustering: BMI vs PhysicalHealthDays')
plt.xlabel('BMI')
plt.ylabel('PhysicalHealthDays')
plt.show()

# Elbow method
inertias = []
silhouette_scores = []
k_range = range(2, 6)  
for k in k_range:
    kmeans.set_params(n_clusters=k)
    kmeans.fit(X_transformed)
    inertias.append(kmeans.inertia_)
    
    # Calculate silhouette score
    cluster_labels = kmeans.predict(X_transformed)
    silhouette_scores.append(silhouette_score(X_transformed, cluster_labels))

# Plot elbow curve
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(k_range, inertias, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.subplot(1, 2, 2)
plt.plot(k_range, silhouette_scores, 'rx-')
plt.xlabel('k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Optimal k')
plt.tight_layout()
plt.show()

# Print cluster centroids
centroids = kmeans.cluster_centers_
print("Cluster Centroids:")
for i, centroid in enumerate(centroids):
    print(f"Cluster {i}:")
    for j in range(centroid.shape[0]):
        print(f"  Component {j}: {centroid[j]:.4f}")
    print()

# Analyze clusters
print("Cluster Analysis:")
for cluster in df['Cluster'].unique():
    cluster_data = df[df['Cluster'] == cluster]
    print(f"Cluster {cluster}:")
    print(cluster_data[numeric_features + ['HadHeartAttack']].describe())
    print(f"Heart Attack Rate: {cluster_data['HadHeartAttack'].mean():.2%}")
    print()
# Out:
# Dimensions after preprocessing: (445132, 121)
# Dimensions after PCA: (445132, 5)
# Cluster Centroids:
# Cluster 0:
#   Component 0: 0.0702
#   Component 1: -0.8756
#   Component 2: -0.4222
#   Component 3: 0.1468
#   Component 4: -0.0594
#
# Cluster 1:
#   Component 0: 0.2992
#   Component 1: 1.9138
#   Component 2: -1.0318
#   Component 3: -0.2104
#   Component 4: 1.4550
#
# Cluster 2:
#   Component 0: 0.8424
#   Component 1: 2.1341
#   Component 2: -0.1768
#   Component 3: 1.1264
#   Component 4: -1.2405
#
# Cluster 3:
#   Component 0: -1.1811
#   Component 1: 0.1089
#   Component 2: 0.5332
#   Component 3: -0.2696
#   Component 4: -0.0344
#
# Cluster 4:
#   Component 0: 2.4460
#   Component 1: -0.4620
#   Component 2: 0.7703
#   Component 3: -0.3942
#   Component 4: 0.1011
#
# Cluster Analysis:
# Cluster 0:
#                  BMI  PhysicalHealthDays  MentalHealthDays     SleepHours  \
# count  360559.000000       360559.000000     360559.000000  360559.000000
# mean       27.873538            1.363644          1.723622       7.118804
# std         5.310433            3.001606          3.614473       1.339830
# min        12.020000            0.000000          0.000000       1.000000
# 25%        24.330000            0.000000          0.000000       6.000000
# 50%        27.860000            0.000000          0.000000       7.000000
# 75%        30.180000            1.000000          2.000000       8.000000
# max        87.530000           30.000000         30.000000      24.000000
#
#        WeightInKilograms  HeightInMeters  HadHeartAttack
# count      360559.000000   360559.000000   360559.000000
# mean           81.473930        1.705620        0.044137
# std            18.467557        0.102715        0.205400
# min            22.680000        0.910000        0.000000
# 25%            68.040000        1.630000        0.000000
# 50%            81.650000        1.700000        0.000000
# 75%            90.720000        1.780000        0.000000
# max           285.000000        2.410000        1.000000
# Heart Attack Rate: 4.41%
#
# Cluster 1:
#                 BMI  PhysicalHealthDays  MentalHealthDays    SleepHours  \
# count  84573.000000        84573.000000      84573.000000  84573.000000
# mean      31.327856           17.070739         15.718849      6.614470
# std        8.453265           12.221325         12.181123      1.968748
# min       12.160000            0.000000          0.000000      1.000000
# 25%       25.830000            4.347919          2.000000      6.000000
# 50%       29.120000           20.000000         15.000000      6.000000
# 75%       35.330000           30.000000         30.000000      8.000000
# max       99.640000           30.000000         30.000000     24.000000
#
#        WeightInKilograms  HeightInMeters  HadHeartAttack
# count       84573.000000    84573.000000    84573.000000
# mean           89.898035        1.690201        0.108711
# std            26.093838        0.106753        0.311278
# min            22.680000        0.910000        0.000000
# 25%            72.570000        1.630000        0.000000
# 50%            83.910000        1.680000        0.000000
# 75%           103.420000        1.750000        0.000000
# max           292.570000        2.410000        1.000000
# Heart Attack Rate: 10.87%
